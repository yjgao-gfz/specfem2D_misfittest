# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
########
#merge two figures

# %%
#####
plt.figure(figsize=[10, 8])
adj_ccc=np.loadtxt('adj_ccc/AA.S0037.BXZ.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0037.BXZ.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0037.BXZ.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0037.BXZ.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0037.BXZ.adj')
misfitname=['CC time shift','multitaper time shift','waveform L2',\
           'TF phase shift','CCC misfit']
wins=[112.5-6, 127.5-6]



waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0037.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0037.BXZ.semd')


plt.subplot(321)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='halfway', linewidth=1)
#plt.text(185,-0.2, 'Receiver 37')
plt.xlim(100,130)
plt.ylim(-1,1)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
plt.text(102,-0.8, 'receiver ID: 37')
plt.legend(loc='lower right',prop={"size":6})
plt.title('Displacement Waveform (Vertical Z)')

plt.subplot(322)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(100,130)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
#plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Adjoint Sources (No time reversal)')


####################################################################


adj_ccc=np.loadtxt('adj_ccc/AA.S0044.BXZ.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0044.BXZ.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0044.BXZ.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0044.BXZ.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0044.BXZ.adj')


wins=[136.5-6,151.5-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0044.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0044.BXZ.semd')
plt.subplot(323)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='halfway', linewidth=1)
plt.text(122,-0.8, 'receiver ID: 44')
plt.xlim(120,150)
plt.ylim(-1,1)
#plt.text(225,-0.2, 'Receiver 44')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 44)')

plt.subplot(324)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(120,150)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)



#####################################################

adj_ccc=np.loadtxt('adj_ccc/AA.S0054.BXZ.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0054.BXZ.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0054.BXZ.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0054.BXZ.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0054.BXZ.adj')


wins=[170.2-6, 185.2-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0054.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0054.BXZ.semd')


plt.subplot(325)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='halfway', linewidth=1)
plt.text(157,-0.8, 'receiver ID: 54')
plt.xlim(155,185)
plt.ylim(-1,1)
#plt.text(285,-0.4, 'Receiver 54')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 54)')



plt.subplot(326)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(155,185)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)

#plt.margins(0.01)
plt.tight_layout()
#plt.gca().add_patch(re)
#plt.legend()
#plt.title('Adjoint Sources (No time reversal)')
plt.savefig('37_44_54_waveform_adjoint.pdf')

# %%
plt.figure(figsize=[10, 8])

adj_ccc=np.loadtxt('adj_ccc_smoothsyn/AA.S0037.BXZ.adj')
adj_cc=np.loadtxt('adj_cc_smoothsyn/AA.S0037.BXZ.adj')
adj_wf=np.loadtxt('adj_wm_smoothsyn/AA.S0037.BXZ.adj')
adj_mt=np.loadtxt('adj_mt_smoothsyn/AA.S0037.BXZ.adj')
adj_ft=np.loadtxt('adj_tf_smoothsyn/AA.S0037.BXZ.adj')
misfitname=['CC time shift','multitaper time shift','waveform L2',\
           'TF phase shift','CCC misfit']
wins=[112.5-6, 127.5-6]


waveform=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0037.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0037.BXZ.semd')


plt.subplot(321)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='halfway', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(102,-0.8, 'receiver ID: 37')
#plt.text(185,-0.2, 'Receiver 37')
plt.xlim(100,130)
plt.ylim(-1,1)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Displacement Waveform (Vertical Z)')

plt.subplot(322)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(100,130)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
#plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Adjoint Sources (No time reversal)')


####################################################################


adj_ccc=np.loadtxt('adj_ccc_smoothsyn/AA.S0044.BXZ.adj')
adj_cc=np.loadtxt('adj_cc_smoothsyn/AA.S0044.BXZ.adj')
adj_wf=np.loadtxt('adj_wm_smoothsyn/AA.S0044.BXZ.adj')
adj_mt=np.loadtxt('adj_mt_smoothsyn/AA.S0044.BXZ.adj')
adj_ft=np.loadtxt('adj_tf_smoothsyn/AA.S0044.BXZ.adj')


wins=[136.5-6,151.5-6]
waveform=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0044.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0044.BXZ.semd')
plt.subplot(323)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='halfway', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(122,-0.8, 'receiver ID: 44')
plt.xlim(120,150)
plt.ylim(-1,1)
#plt.text(225,-0.2, 'Receiver 44')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 44)')

plt.subplot(324)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(120,150)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)



#####################################################

adj_ccc=np.loadtxt('adj_ccc_smoothsyn/AA.S0054.BXZ.adj')
adj_cc=np.loadtxt('adj_cc_smoothsyn/AA.S0054.BXZ.adj')
adj_wf=np.loadtxt('adj_wm_smoothsyn/AA.S0054.BXZ.adj')
adj_mt=np.loadtxt('adj_mt_smoothsyn/AA.S0054.BXZ.adj')
adj_ft=np.loadtxt('adj_tf_smoothsyn/AA.S0054.BXZ.adj')


wins=[170.2-6, 185.2-6]
waveform=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0054.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0054.BXZ.semd')


plt.subplot(325)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='halfway', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.xlim(155,185)
plt.text(157,-0.8, 'receiver ID: 54')
plt.ylim(-1,1)
#plt.text(285,-0.4, 'Receiver 54')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 54)')



plt.subplot(326)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(155,185)

plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)

#plt.margins(0.01)
plt.tight_layout()
#plt.gca().add_patch(re)
#plt.legend()
#plt.title('Adjoint Sources (No time reversal)')
plt.savefig('37_44_54_waveform_adjoint_smoothvshomo.pdf')

# %%
plt.figure(figsize=[10, 8])

adj_ccc=np.loadtxt('adj_ccc_anomalysyn/AA.S0037.BXZ.adj')
adj_cc=np.loadtxt('adj_cc_anomalysyn/AA.S0037.BXZ.adj')
adj_wf=np.loadtxt('adj_wm_anomalysyn/AA.S0037.BXZ.adj')
adj_mt=np.loadtxt('adj_mt_anomalysyn/AA.S0037.BXZ.adj')
adj_ft=np.loadtxt('adj_tf_anomalysyn/AA.S0037.BXZ.adj')
misfitname=['CC time shift','multitaper time shift','waveform L2',\
           'TF phase shift','CCC misfit']
wins=[112.5-6, 127.5-6]



waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0037.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0037.BXZ.semd')


plt.subplot(321)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(102,-0.8, 'receiver ID: 37')
#plt.text(185,-0.2, 'Receiver 37')
plt.xlim(100,130)
plt.ylim(-1,1)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Displacement Waveform (Vertical Z)')

plt.subplot(322)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(100,130)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
#plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Adjoint Sources (No time reversal)')


####################################################################


adj_ccc=np.loadtxt('adj_ccc_anomalysyn/AA.S0044.BXZ.adj')
adj_cc=np.loadtxt('adj_cc_anomalysyn/AA.S0044.BXZ.adj')
adj_wf=np.loadtxt('adj_wm_anomalysyn/AA.S0044.BXZ.adj')
adj_mt=np.loadtxt('adj_mt_anomalysyn/AA.S0044.BXZ.adj')
adj_ft=np.loadtxt('adj_tf_anomalysyn/AA.S0044.BXZ.adj')


wins=[136.5-6,151.5-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0044.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0044.BXZ.semd')
plt.subplot(323)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.xlim(120,150)
plt.ylim(-1,1)
plt.text(122,-0.8, 'receiver ID: 44')
#plt.text(225,-0.2, 'Receiver 44')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 44)')

plt.subplot(324)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(120,150)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)



#####################################################

adj_ccc=np.loadtxt('adj_ccc_anomalysyn/AA.S0054.BXZ.adj')
adj_cc=np.loadtxt('adj_cc_anomalysyn/AA.S0054.BXZ.adj')
adj_wf=np.loadtxt('adj_wm_anomalysyn/AA.S0054.BXZ.adj')
adj_mt=np.loadtxt('adj_mt_anomalysyn/AA.S0054.BXZ.adj')
adj_ft=np.loadtxt('adj_tf_anomalysyn/AA.S0054.BXZ.adj')


wins=[170.2-6, 185.2-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0054.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0054.BXZ.semd')


plt.subplot(325)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(157,-0.8, 'receiver ID: 54')
plt.xlim(155,185)
plt.ylim(-1,1)
#plt.text(285,-0.4, 'Receiver 54')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 54)')



plt.subplot(326)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(155,185)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)

#plt.margins(0.01)
plt.tight_layout()
#plt.gca().add_patch(re)
#plt.legend()
#plt.title('Adjoint Sources (No time reversal)')
plt.savefig('37_44_54_waveform_adjoint_anomalyvshomo.pdf')

# %%
plt.figure(figsize=[10, 8])

adj_ccc=np.loadtxt('adj_ccc_anomalysyn/AA.S0037.BXX.adj')
adj_cc=np.loadtxt('adj_cc_anomalysyn/AA.S0037.BXX.adj')
adj_wf=np.loadtxt('adj_wm_anomalysyn/AA.S0037.BXX.adj')
adj_mt=np.loadtxt('adj_mt_anomalysyn/AA.S0037.BXX.adj')
adj_ft=np.loadtxt('adj_tf_anomalysyn/AA.S0037.BXX.adj')
misfitname=['CC time shift','multitaper time shift','waveform L2',\
           'TF phase shift','CCC misfit']
wins=[112.5-6, 127.5-6]



waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0037.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0037.BXX.semd')


plt.subplot(321)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(102,-0.8, 'receiver ID: 37')
#plt.text(185,-0.2, 'Receiver 37')
plt.xlim(100,130)
plt.ylim(-1,1)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Displacement Waveform (Horizontal X)')

plt.subplot(322)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(100,130)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
#plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Adjoint Sources (No time reversal)')


####################################################################


adj_ccc=np.loadtxt('adj_ccc_anomalysyn/AA.S0044.BXX.adj')
adj_cc=np.loadtxt('adj_cc_anomalysyn/AA.S0044.BXX.adj')
adj_wf=np.loadtxt('adj_wm_anomalysyn/AA.S0044.BXX.adj')
adj_mt=np.loadtxt('adj_mt_anomalysyn/AA.S0044.BXX.adj')
adj_ft=np.loadtxt('adj_tf_anomalysyn/AA.S0044.BXX.adj')


wins=[136.5-6,151.5-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0044.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0044.BXX.semd')
plt.subplot(323)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.xlim(120,150)
plt.ylim(-1,1)
plt.text(122,-0.8, 'receiver ID: 44')
#plt.text(225,-0.2, 'Receiver 44')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 44)')

plt.subplot(324)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(120,150)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)



#####################################################

adj_ccc=np.loadtxt('adj_ccc_anomalysyn/AA.S0054.BXX.adj')
adj_cc=np.loadtxt('adj_cc_anomalysyn/AA.S0054.BXX.adj')
adj_wf=np.loadtxt('adj_wm_anomalysyn/AA.S0054.BXX.adj')
adj_mt=np.loadtxt('adj_mt_anomalysyn/AA.S0054.BXX.adj')
adj_ft=np.loadtxt('adj_tf_anomalysyn/AA.S0054.BXX.adj')


wins=[170.2-6, 185.2-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0054.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0054.BXX.semd')


plt.subplot(325)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(157,-0.8, 'receiver ID: 54')
plt.xlim(155,185)
plt.ylim(-1,1)
#plt.text(285,-0.4, 'Receiver 54')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 54)')



plt.subplot(326)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(155,185)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)

#plt.margins(0.01)
plt.tight_layout()
#plt.gca().add_patch(re)
#plt.legend()
#plt.title('Adjoint Sources (No time reversal)')
plt.savefig('37_44_54_waveform_adjoint_anomalyvshomoX.pdf')

# %%
#####
plt.figure(figsize=[10, 8])
adj_ccc=np.loadtxt('adj_ccc/AA.S0037.BXX.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0037.BXX.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0037.BXX.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0037.BXX.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0037.BXX.adj')
misfitname=['CC time shift','multitaper time shift','waveform L2',\
           'TF phase shift','CCC misfit']
wins=[112.5-6, 127.5-6]



waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0037.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0037.BXX.semd')


plt.subplot(321)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='halfway', linewidth=1)
#plt.text(185,-0.2, 'Receiver 37')
plt.xlim(100,130)
plt.ylim(-1,1)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
plt.text(102,-0.8, 'receiver ID: 37')
plt.legend(loc='lower right',prop={"size":6})
plt.title('Displacement Waveform (Horizontal X)')

plt.subplot(322)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(100,130)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
#plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Adjoint Sources (No time reversal)')


####################################################################


adj_ccc=np.loadtxt('adj_ccc/AA.S0044.BXX.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0044.BXX.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0044.BXX.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0044.BXX.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0044.BXX.adj')


wins=[136.5-6,151.5-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0044.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0044.BXX.semd')
plt.subplot(323)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='halfway', linewidth=1)
plt.text(122,-0.8, 'receiver ID: 44')
plt.xlim(120,150)
plt.ylim(-1,1)
#plt.text(225,-0.2, 'Receiver 44')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 44)')

plt.subplot(324)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(120,150)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)



#####################################################

adj_ccc=np.loadtxt('adj_ccc/AA.S0054.BXX.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0054.BXX.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0054.BXX.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0054.BXX.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0054.BXX.adj')


wins=[170.2-6, 185.2-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0054.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0054.BXX.semd')


plt.subplot(325)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='target', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='halfway', linewidth=1)
plt.text(157,-0.8, 'receiver ID: 54')
plt.xlim(155,185)
plt.ylim(-1,1)
#plt.text(285,-0.4, 'Receiver 54')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 54)')



plt.subplot(326)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(155,185)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)

#plt.margins(0.01)
plt.tight_layout()
#plt.gca().add_patch(re)
#plt.legend()
#plt.title('Adjoint Sources (No time reversal)')
plt.savefig('37_44_54_waveform_adjointX.pdf')

# %%
plt.figure(figsize=[10, 8])

adj_ccc=np.loadtxt('adj_ccc_smoothsyn/AA.S0037.BXX.adj')
adj_cc=np.loadtxt('adj_cc_smoothsyn/AA.S0037.BXX.adj')
adj_wf=np.loadtxt('adj_wm_smoothsyn/AA.S0037.BXX.adj')
adj_mt=np.loadtxt('adj_mt_smoothsyn/AA.S0037.BXX.adj')
adj_ft=np.loadtxt('adj_tf_smoothsyn/AA.S0037.BXX.adj')
misfitname=['CC time shift','multitaper time shift','waveform L2',\
           'TF phase shift','CCC misfit']
wins=[112.5-6, 127.5-6]


waveform=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0037.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0037.BXX.semd')


plt.subplot(321)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='halfway', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(102,-0.8, 'receiver ID: 37')
#plt.text(185,-0.2, 'Receiver 37')
plt.xlim(100,130)
plt.ylim(-1,1)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Displacement Waveform (Horizontal X)')

plt.subplot(322)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(100,130)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
#plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Adjoint Sources (No time reversal)')


####################################################################


adj_ccc=np.loadtxt('adj_ccc_smoothsyn/AA.S0044.BXX.adj')
adj_cc=np.loadtxt('adj_cc_smoothsyn/AA.S0044.BXX.adj')
adj_wf=np.loadtxt('adj_wm_smoothsyn/AA.S0044.BXX.adj')
adj_mt=np.loadtxt('adj_mt_smoothsyn/AA.S0044.BXX.adj')
adj_ft=np.loadtxt('adj_tf_smoothsyn/AA.S0044.BXX.adj')


wins=[136.5-6,151.5-6]
waveform=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0044.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0044.BXX.semd')
plt.subplot(323)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='halfway', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.text(122,-0.8, 'receiver ID: 44')
plt.xlim(120,150)
plt.ylim(-1,1)
#plt.text(225,-0.2, 'Receiver 44')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 44)')

plt.subplot(324)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(120,150)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)



#####################################################

adj_ccc=np.loadtxt('adj_ccc_smoothsyn/AA.S0054.BXX.adj')
adj_cc=np.loadtxt('adj_cc_smoothsyn/AA.S0054.BXX.adj')
adj_wf=np.loadtxt('adj_wm_smoothsyn/AA.S0054.BXX.adj')
adj_mt=np.loadtxt('adj_mt_smoothsyn/AA.S0054.BXX.adj')
adj_ft=np.loadtxt('adj_tf_smoothsyn/AA.S0054.BXX.adj')


wins=[170.2-6, 185.2-6]
waveform=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0054.BXX.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_SYN/AA.S0054.BXX.semd')


plt.subplot(325)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='halfway', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='1D', linewidth=1)
plt.xlim(155,185)
plt.text(157,-0.8, 'receiver ID: 54')
plt.ylim(-1,1)
#plt.text(285,-0.4, 'Receiver 54')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 54)')



plt.subplot(326)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(155,185)

plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)

#plt.margins(0.01)
plt.tight_layout()
#plt.gca().add_patch(re)
#plt.legend()
#plt.title('Adjoint Sources (No time reversal)')
plt.savefig('37_44_54_waveform_adjoint_smoothvshomoX.pdf')

# %%
plt.figure(figsize=[10, 8])

adj_ccc=np.loadtxt('adj_ccc/AA.S0037.BXX.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0037.BXX.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0037.BXX.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0037.BXX.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0037.BXX.adj')
misfitname=['CC time shift','multitaper time shift','waveform L2',\
           'TF phase shift','CCC misfit']
wins=[112.5-6, 127.5-6]



waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0037.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0037.BXZ.semd')


plt.subplot(321)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='anomaly', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='anomaly_smooth', linewidth=1)
#plt.text(185,-0.2, 'Receiver 37')
plt.xlim(100,130)
plt.ylim(-1,1)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Displacement Waveform (Horizontal X)')

plt.subplot(322)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'lightblue',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(100,130)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
#plt.gca().add_patch(re)
plt.legend(loc='lower right',prop={"size":6})
plt.title('Adjoint Sources (No time reversal)')


####################################################################


adj_ccc=np.loadtxt('adj_ccc/AA.S0044.BXX.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0044.BXX.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0044.BXX.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0044.BXX.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0044.BXX.adj')


wins=[136.5-6,151.5-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0044.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0044.BXZ.semd')
plt.subplot(323)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='anomaly', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='anomaly_smooth', linewidth=1)
plt.xlim(120,150)
plt.ylim(-1,1)
#plt.text(225,-0.2, 'Receiver 44')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 44)')

plt.subplot(324)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'lightblue',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)


plt.xlim(120,150)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)



#####################################################

adj_ccc=np.loadtxt('adj_ccc/AA.S0054.BXX.adj')
adj_cc=np.loadtxt('adj_cc/AA.S0054.BXX.adj')
adj_wf=np.loadtxt('adj_wm/AA.S0054.BXX.adj')
adj_mt=np.loadtxt('adj_mt/AA.S0054.BXX.adj')
adj_ft=np.loadtxt('adj_tf/AA.S0054.BXX.adj')


wins=[170.2-6, 185.2-6]
waveform=np.loadtxt('EVENT1/REF_SEM/AA.S0054.BXZ.semd')
waveform_smooth=np.loadtxt('EVENT1/REF_SEM_smooth/AA.S0054.BXZ.semd')


plt.subplot(325)
plt.plot(waveform.T[0],waveform.T[1]/np.max(waveform.T[1]),'b',label='anomaly', linewidth=1)
plt.plot(waveform_smooth.T[0],waveform_smooth.T[1]/np.max(waveform_smooth.T[1]),'k',label='anomaly_smooth', linewidth=1)
plt.xlim(155,185)
plt.ylim(-1,1)
#plt.text(285,-0.4, 'Receiver 54')
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)
plt.gca().add_patch(re)
#plt.legend()
#plt.title('Waveform (receiver 54)')



plt.subplot(326)

plt.plot(adj_ccc.T[0],adj_wf.T[1]/np.max(adj_wf.T[1]),'grey',label='waveform L2', linewidth=3)
plt.plot(adj_ccc.T[0],adj_mt.T[1]/np.max(adj_mt.T[1]),'green',label='multitaper time shift', linewidth=2)
plt.plot(adj_ccc.T[0],adj_cc.T[1]/np.max(adj_cc.T[1]),'k',label='CC time shift', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ccc.T[1]/np.max(adj_ccc.T[1]),'b',label='CCC misfit', linewidth=1)
plt.plot(adj_ccc.T[0],adj_ft.T[1]/np.max(adj_ft.T[1]),'red',label='TF phase shift', linewidth=1)
plt.xlim(155,185)
plt.ylim(-1.2,1.2)
re = patches.Rectangle((wins[0], plt.ylim()[0]),
                               wins[1] - wins[0],
                               plt.ylim()[1] - plt.ylim()[0],
                               color="lightblue", alpha=0.6)

#plt.margins(0.01)
plt.tight_layout()
#plt.gca().add_patch(re)
#plt.legend()
#plt.title('Adjoint Sources (No time reversal)')
plt.savefig('37_44_54_waveform_adjoint_X.pdf')
